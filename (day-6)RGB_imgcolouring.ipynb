# %%
import numpy as np
from PIL import Image  
import matplotlib.pyplot as plt

img = Image.open(r"C:\Users\ADMIN\OneDrive\Desktop\ds\image.avif")
img = np.array(img)
img[:, :, 0] = np.clip(img[:, :, 0] + 100, 0, 255)

plt.imshow(img)
plt.axis("off")
plt.show()

# %%
h, w, c = img.shape    
mid_h=h//2
mid_w=w//2
img[0:mid_h, 0:mid_w,2]=100 #top left 
img[0:mid_h,mid_w:w,0]=255 
img[mid_h:h, 0:mid_w,1]=255
img[mid_h:h, mid_w:w,0]=255
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# RGB=[0,1,2]
